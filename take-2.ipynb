# %% [markdown]
# goal of take 2: understand the data with the use of visual aids
#
# noted_features:
#      + time of travel
#      + day (time of year) of travel
#      + origin town
#      + type of car (vehicle)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from collections import Counter

# %%
# read, parse and clean data
raw_data = pd.read_csv('data/train_data.csv')
raw_data.dropna()

ticket_count = Counter(raw_data['ride_id'])
# count the number of times a ride occurs..
# tells the number of ticekts sold to that ride

raw_data.drop(columns=['seat_number', 'payment_method', 'payment_receipt', 'travel_to', 'max_capacity'])
raw_data.drop_duplicates()
# Out:
#       ride_id seat_number payment_method payment_receipt travel_date  \
# 0        1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1        5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2        5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3        5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4        5778         11A          Mpesa      BM97HFRGL9    27-11-17
# 5        5777         18B          Mpesa      B6PBDU30IZ    27-11-17
# 6        5777         14A          Mpesa      MZHGDGS6QZ    27-11-17
# 7        5778          25          Mpesa      MYVTYFNXDZ    27-11-17
# 8        5778         21B          Mpesa      TE1WYK1NYE    27-11-17
# 9        5781         22A          Mpesa      VGG7Q3MVJX    27-11-17
# 10       5781         18B          Mpesa      YJ7JFHOGKA    27-11-17
# 11       5781         17B          Mpesa      4JQOSC881A    27-11-17
# 12       5784          1X          Mpesa      3OPU23FHRB    20-04-18
# ...

# %% [markdown]
# for each bin of ticket sales, observe the distibution of payment method
# repeat for car type
#
# question: for ticket sales under 10, who sells more, bus or shuttle?
# what of for ticket sales above 20:
#
# for example, shuttles can not sell more than 11 tickets
